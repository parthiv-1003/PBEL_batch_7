# %%
import pandas as pd

# %%
data = pd.read_csv("DATA/matches.csv")

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             39 non-null     int64
#  1   date                 39 non-null     str
#  2   venue                39 non-null     str
#  3   team1                39 non-null     str
#  4   team2                39 non-null     str
#  5   stage                39 non-null     str
#  6   toss_winner          39 non-null     str
#  7   toss_decision        39 non-null     str
#  8   first_ings_score     38 non-null     float64
#  9   first_ings_wkts      38 non-null     float64
#  10  second_ings_score    38 non-null     float64
#  11  second_ings_wkts     38 non-null     float64
#  12  match_result         39 non-null     str
#  13  match_winner         38 non-null     str
#  14  wb_runs              15 non-null     float64
#  15  wb_wickets           22 non-null     float64
# ...

# %%
data.isnull()
# Out:
#     match_id   date  venue  team1  team2  stage  toss_winner  toss_decision  \
# 0      False  False  False  False  False  False        False          False
# 1      False  False  False  False  False  False        False          False
# 2      False  False  False  False  False  False        False          False
# 3      False  False  False  False  False  False        False          False
# 4      False  False  False  False  False  False        False          False
# 5      False  False  False  False  False  False        False          False
# 6      False  False  False  False  False  False        False          False
# 7      False  False  False  False  False  False        False          False
# 8      False  False  False  False  False  False        False          False
# 9      False  False  False  False  False  False        False          False
# 10     False  False  False  False  False  False        False          False
# ...

# %%
data.isnull().any()
# Out:
# match_id               False
# date                   False
# venue                  False
# team1                  False
# team2                  False
# stage                  False
# toss_winner            False
# toss_decision          False
# first_ings_score        True
# first_ings_wkts         True
# second_ings_score       True
# second_ings_wkts        True
# match_result           False
# match_winner            True
# balls_left              True
# player_of_the_match     True
# top_scorer              True
# highscore               True
# best_bowling            True
# best_bowling_figure     True
# super_over_match       False
# dtype: bool

# %%
data.dropna(inplace = True)

# %%
data.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  38.000000         38.000000        38.000000          38.000000
# mean   20.210526        190.526316         6.289474         175.500000
# std    11.477729         39.394565         2.470451          39.747684
# min     1.000000         75.000000         2.000000          77.000000
# 25%    10.250000        159.750000         4.250000         159.250000
# 50%    20.500000        197.000000         6.000000         180.000000
# 75%    29.750000        215.000000         8.000000         203.750000
# max    39.000000        264.000000        10.000000         265.000000
#
#        second_ings_wkts  balls_left   highscore
# count         38.000000   38.000000   38.000000
# mean           6.052632   10.684211   79.447368
# std            2.670635   15.773918   24.521031
# min            1.000000    0.000000   34.000000
# 25%            4.000000    0.250000   60.750000
# ...

# %%
data['venue'].value_counts()
# Out:
# venue
# M. Chinnaswamy Stadium, Bangalore                5
# Wankhede Stadium, Mumbai                         4
# Ekana Cricket Stadium, Lucknow                   4
# Arun Jaitley Stadium, Delhi                      4
# Narendra Modi Stadium, Ahmedabad                 4
# Rajiv Gandhi International Stadium, Hyderabad    4
# Barsapara Stadium, Guwahati                      3
# New PCA Cricket Stadium, Mullanpur               3
# Eden Gardens, Kolkata                            3
# MA Chidambaram Stadium, Chennai                  3
# Sawai Mansingh Stadium, Jaipur                   1
# Name: count, dtype: int64

# %%
#select data
data.iloc[2:6,1:7]   #slicing
# Out:
#              date                               venue team1 team2   stage  \
# 2  March 30, 2026         Barsapara Stadium, Guwahati    RR   CSK  League
# 3  March 31, 2026  New PCA Cricket Stadium, Mullanpur  PBKS    GT  League
# 4  April 01, 2026      Ekana Cricket Stadium, Lucknow   LSG    DC  League
# 5  April 02, 2026               Eden Gardens, Kolkata   KKR   SRH  League
#
#   toss_winner
# 2          RR
# 3        PBKS
# 4          DC
# 5         KKR

# %%
rcb_tw = data['toss_winner']=='RCB'
cst = data['venue']=='M. Chinnaswamy Stadium, Bangalore'

# %%
data[rcb_tw & cst]
# Out:
#     match_id            date                              venue team1 team2  \
# 0          1  March 28, 2026  M. Chinnaswamy Stadium, Bangalore   RCB   SRH
# 22        23  April 15, 2026  M. Chinnaswamy Stadium, Bangalore   RCB   LSG
# 33        34  April 24, 2026  M. Chinnaswamy Stadium, Bangalore   RCB    GT
#
#      stage toss_winner toss_decision  first_ings_score  first_ings_wkts  ...  \
# 0   League         RCB          Bowl             201.0              9.0  ...
# 22  League         RCB          Bowl             146.0             10.0  ...
# 33  League         RCB          Bowl             205.0              3.0  ...
#
#     second_ings_wkts  match_result match_winner balls_left  \
# 0                4.0     completed          RCB       26.0
# 22               5.0     completed          RCB       29.0
# 33               5.0     completed          RCB        7.0
#
#     player_of_the_match     top_scorer highscore  best_bowling  \
# ...
