# %%
# variable int, float string, boolean, complex, list, tuple, dict, set, class
a = 12 #var opt value #dynamically typed language 
print(a)
print(type(a))
# Out:
# 12
# <class 'int'>

# %%
user = input("Enter your name: ")
print("Hello",user)
print(type(user))
# Out:
# Hello PArthiv
# <class 'str'>

# %%
user_num = int(input("Enter you number "))
print("hello", user_num)
print(type(user_num))
# Out:
# hello 100
# <class 'int'>

# %%
a = 10.56  #float number
print(a)
b = 2 +3j  #complex number
print(b)
c = True #boolean
print(c)
d = "hello World"  #string 
print(d)
e = 'a'  #string
print(e)
f = """she said "hello to you don't you know?" """ #string 
print(f)
# Out:
# 10.56
# (2+3j)
# True
# hello World
# a
# she said "hello to you don't you know?"

# %%
a = 10, 2,3,4,5
print(type(a))
# Out:
# <class 'tuple'>

# %%
a= () #tuple
b= [] # list
c= {'k':'v'} #dict 
d= {} #set
