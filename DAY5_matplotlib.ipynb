# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("DATA/tipsdataset.csv")

# %%
data.sample()
# Out:
#     total_bill   tip  gender smoker  day    time  size
# 94       22.75  3.25  Female     No  Fri  Dinner     2

# %%
plt.plot(data['total_bill'])
plt.show()

# %%
plt.scatter(data["size"], data['tip'],s =data['total_bill'])

# %%
#plt.bar() bi num-catagoric
plt.bar(data["size"],data['tip'])
# Out:
# <BarContainer object of 244 artists>

# %%
plt.pie(data['tip'], data ['total_bill'])
# Out:
# C:\Users\Parthiv Patel\AppData\Local\Temp\ipykernel_18824\1001172150.py:1: MatplotlibDeprecationWarning: Passing the explode parameter of pie() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.pie(data['tip'], data ['total_bill'])
