# %%
#conditional statment: if, if else, if elif else
#looping statement : for, while
#jumping statement : break, continue, pass

# %%
#conditional Statement 
age = 19
if(age>18):
    print("you are eligible for voting...")
elif age == 18:
     print("you are eligible to vote ....")
# Out:
# you are eligible for voting...

# %%
#loop statement : for and while 
list1 = [1,2,3,4,5]
for x in list1:
    print(x)

for x in range(4, 10):
    print(x)
i = 1
while i<list1:
    print(i)
    i = i+1
# Out:
# 1
# 2
# 3
# 4
# 5
# 4
# 5
# 6
# 7
# 8
# 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       5
#       6 for x in range(4, 10):
#       7     print(x)
#       8 i = 1
# ----> 9 while i<list1:
#      10     print(i)
#      11     i = i+1
#
# TypeError: '<' not supported between instances of 'int' and 'list'

# %%
#create a program where the user will enter a number and the program will 
# add all number one by one and print the result  
ans = "y"
list = []
while(ans != "q"):
    num = int(input("enter a number :"))
    ans = input("Do you want to enter a number: (y\q)")
    list.append(num)

for i in list:
    print(i)
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\q'
# <>:7: SyntaxWarning: invalid escape sequence '\q'
# C:\Users\Parthiv Patel\AppData\Local\Temp\ipykernel_5000\2518569078.py:7: SyntaxWarning: invalid escape sequence '\q'
#   ans = input("Do you want to enter a number: (y\q)")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 #create a program where the user will enter a number and the program will
#       2 # add all number one by one and print the result
#       3
#       4 list = []
# ----> 5 while(ans != "q"):
#       6     num = int(input("enter a number :"))
#       7     ans = input("Do you want to enter a number: (y\q)")
#       8     list.append(num)
#
# NameError: name 'ans' is not defined
